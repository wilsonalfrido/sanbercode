# %% [markdown]
# <h2>Soal 1:</h2>
#
# Dengan menggunakan data di bawah ini, plot kan data tersebut kemudian custom sehingga memiliki result seperti yang di harapkan :
#
# note: warna terdiri dari warna Hijau, kuning, Biru, dan Merah

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
cos = np.cos(x)
cos3 = np.cos(x)*3
sin = np.sin(x-90)
sin2 = np.sin(x)*2

# %%
fig, ax  = plt.subplots(figsize=(8.5,5.5))
plt.plot(x,cos, color = 'red', label = 'Cosx')
plt.plot(x,cos3, color = 'green', linestyle = '--', label = '3 Cosx')
plt.plot(x,sin, color = 'blue', linestyle = '-.', label = 'Sin(x-90)')
plt.plot(x,sin2, color = 'yellow', linestyle = 'none', marker = 'x', label = '2 Sinx')
plt.legend(loc=  'center', framealpha = 0.5)
ax.set_xlabel('X-Axis label')
ax.set_ylabel('Y-Axis label')
ax.set_title('Grafik Cos Sin')
plt.show()

# %% [markdown]
# Expected Result:
#
# ![alt text](https://drive.google.com/uc?id=1XRcfWyiWLDmriw7s7U4fTn5Gs6s2qf5o)
