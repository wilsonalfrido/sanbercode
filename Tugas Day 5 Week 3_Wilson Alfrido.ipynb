# %%
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df = sns.load_dataset('diamonds')
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# # Soal 1: Scatter Plot

# %% [markdown]
# Buatlah scatterplot menggunakan Seaborn dari data df di atas, variasikan menggunakan palette yang telah disediakan sehingga didapatkan output sesuai expected.

# %%
sns.set({'figure.figsize':(13,13)})
palette = "ch:r=-.2,d=.3_r"
sns.scatterplot(data = df, x = 'carat', y ='price', hue = 'clarity',size = 'depth',palette = 'ch:r=-.2,d=.3_r', linewidth = 0, sizes = (3,9))
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1JLtkSpx0TfSF7fMSBcZuXaY_tNkR5LYc)

# %% [markdown]
# # Soal 2: Catplot

# %% [markdown]
# Buatlah sebuah Categorical plot dengan kind = 'boxplot', sehingga diperoleh hasil seperti expected output berikut:

# %%
#code here
with sns.axes_style(style='ticks'):
    ax = sns.catplot(x='clarity',y='price',data = df, col = 'cut', kind = 'box',showfliers = False)
    ax.set(xlabel = 'Clarity', ylabel = 'Price')

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=17mSiL-qQtFB2D8rUYB0v7d6tOrOHDoh6)

# %% [markdown]
# # Soal 3: Pair Plot

# %% [markdown]
# Ambil 300 data secara acak dari df, kemudian buat pair plotnya dari 300 data tersebut untuk kolom carat, depth, table, dan price serta markers =  ['p', 'o', 's', 'D', 'X'] sehingga dihasilkan output sesuai expected.

# %%
df2 = df.sample(n=300, random_state=123)
sns.pairplot(data = df2, hue = 'cut', corner = True, vars = ['carat','depth','table','price'],markers = ['p', 'o', 's', 'D', 'X'])

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=12rStINwUNGpqZd1iIGaqzTIvw9irAkJ0)

# %% [markdown]
# # Soal 4: Joint Plot

# %% [markdown]
# Gunakan data yang sama dengan soal 3 untuk menghasilkan dua visualisasi joint plot antara carat dan price nya sesuai expected output.

# %%
#code here
with sns.axes_style('white'):
    display(sns.jointplot(x = df2['carat'],y = df2['price'], kind = 'kde'))
with sns.axes_style('darkgrid'):
    display(sns.jointplot(x = df2['carat'],y = df2['price'], kind = 'reg'))

# %% [markdown]
# Expected Output 1:
#
# ![alt text](https://drive.google.com/uc?id=17MY9L4bUSxuCIRxDl7Ey34_RrfXjlcim)
#
# Expected Output 2:
#
# ![alt text](https://drive.google.com/uc?id=1A5vQ66KLZ9sbJ_qDoAkuAF3Z213ricZW)
