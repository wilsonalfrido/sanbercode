# %% [markdown]
# # Soal 1: Pemahaman Teori
# Jelaskan perbedaan antara Univariate, Bivariate dan Multivariate Analysis

# %% [markdown]
# Jawaban:

# %% [markdown]
# Univariate analysis adalah analisis data hanya pada satu variabel. Karena hanya analisis pada satu variabel saja, maka hasil analisis yang diperoleh bukan bersifat hubungan/sebab-akibat, melainkan untuk mendeskripsikan frekuensi persebaran atau pola dan pada data dalam satu variabel. Hubungan univariate dapat di-visualisasikan menggunakan bar chart, pie chart, polygon, dan histogram
#
# ---
# Bivariate analysis adalah analisis data yang dilakukan pada 2 variabel data. Tujuan dari analisis tersebut adalah untuk mendeskripsikan hubungan antara 2 variabel. Hubungan variabel tersebut dapat dilihat melalui koefisien korelasi, yang mana jika nilainya mendekati 1, maka terdapat hubungan linear dengan gradien positif , jika -1 maka gradiennya negatif, serta jika mendekati 0, maka tidak terdapat hubungan. Meskipun memiliki hubungan yang kuat, tidak menjadi jaminan bahwa suatu variabel adalah penyebab variabel lainnya terjadi atau biasa disebut "correlation is not causation". Hal tersebut dapat terjadi karena adanya faktor lain tambahan yang sebenarnya mempengaruhi salah satu nilai variabel. Hubungan bivariate dapat digambarkan menggunakan scatter plot, hexbin plot, mosaic plot, heatmaps, dan linechart.
#
#
# ---
#
# Multivariate analysis adalah analisis lebih dari 2 variabel data secara bersamaan. Pada analisis tersebut terdapat minimal satu variabel terikat dan lebih dari satu variabel bebas.
#
# ---
#
# Berdasarkan penjelasan di atas, maka terlihat bahwa perbedan ketiga jenis analisis tersebut adalah terletak pada jumlah variabel yang dianalisis.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 2. Persiapan Data
#
# *   Hapus nilai missing dalam rows dataset menggunakan atribut.dropna()
#
# *   Lakukan grouping data berdasarkan kolom 'species' dengan menggunakan agregasi mean()

# %%
#drop missing values
df.dropna(axis = 0, inplace = True)
#grouping data
df_group = df.groupby(['species']).mean().copy()
df_group
# Out:
#            bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# species
# Adelie          38.823973      18.347260         190.102740  3706.164384
# Chinstrap       48.833824      18.420588         195.823529  3733.088235
# Gentoo          47.568067      14.996639         217.235294  5092.436975

# %% [markdown]
# Expected output:
#
# ![tanpa handling missing value](https://drive.google.com/uc?id=1OnuXmscVRqduqT_TYI1vB291rpXM4D_1)

# %% [markdown]
# # Soal 3. Univariate Analysis
# Buatlah sebuah analisa univariate dengan menggunakan perintah seperti berikut:
#
# *   Buatlah sebuah Pie plot dari dataset hasil grouping untuk kolom flipper_length_mm seperti expected output berikut:
# *   Buatlah sebuah plot histogram dari dataset awal (sebelum grouping) untuk kolom body_mass_g
# *   Jelaskan insight yang diperoleh dari ke dua grafik tersebut.

# %%
#pie
print("Pie Chart")
ax, fig = plt.subplots(figsize = (12,8))
plt.pie(df_group['flipper_length_mm'], labels = df_group.index,autopct='%1.1f%%')
plt.show()
#hist
print("Histogram")
fig2, ax2 = plt.subplots(figsize = (10,8))
plt.hist(df['body_mass_g'])
ax2.set(xlabel = 'Body_mass_g', ylabel = 'Count')
plt.show()
# Out:
# Pie Chart
# Histogram

# %% [markdown]
# Expected Output:
#
#
# Pie Chart
#
# ![](https://drive.google.com/uc?id=11H6X7xpEeodPWD56tHBhV4sLrJ-6B-Bd)
#
# Histogram
#
# ![](https://drive.google.com/uc?id=1A_twS7BbQhkGvUz7zAWgye7q3ZRTQkhi)

# %% [markdown]
# Analisa:

# %% [markdown]
# ---
#
# Berdasarkan pie chart, diperoleh bahwa jenis penguin dengan rata - rata panjang sirip terbesar adalah jenis gentoo, lalu disusul oleh chinstrap, dan yang paling pendek adalah adelie.
#
#
# ---
#
# Berdasarkan grafik histogram,  paling banyak berat penguin berkisar pada rentang nilai sekitar 3500g - 4000g. Rentang berat badan penguin tersebut didominasi oleh jenis adelie dan chinstrap jika melihat nilai rata - rata yang terdapat pada no 2. Hal tersebut disebabkan berat badan penguin jenis gentoo memiliki rata -rata  yang sangat besar, yakni berkisar 5000g dan jika dibandingkan dengan 2 jenis lainnya, rata - rata berat badannya lebih kecil, yakni sekitar 3700g.
#
# ---

# %% [markdown]
# # Soal 4. Bivariate Analysis
#
#
#
# *   Buatlah sebuah grafik catplot menggunakan seaborn dengan x='sex', y='bill_length_mm' dan kind 'bar' seperti expected output di bawah
# *   Buatlah sebuah grafik scatter plot menggunakan seaborn dengan x='body_mass_g', y='flipper_length_mm', hue='bill_length_mm' seperti expected dibawah
# *   Jelaskan insight yang diperoleh dari hasil analisa bivariate tersebut

# %%
print("Catplot")
sns.catplot(data = df, x = 'sex', y = 'bill_length_mm', kind = 'bar')
plt.show()
print("Scatter plot")
plt.figure(figsize = (12,8))
sns.scatterplot(data = df, x='body_mass_g', y='flipper_length_mm', hue = 'bill_length_mm')
plt.show()
# Out:
# Catplot
# Scatter plot

# %% [markdown]
# Expected Output:
#
# Catplot
#
# ![](https://drive.google.com/uc?id=1imCbGD9cWqXUjd33tAh6D0OH20vVpWea)
#
# Scatter plot
#
# ![](https://drive.google.com/uc?id=1_k734IpRYq6Q1wF57hwzSEjnVd2Sii2Z)

# %% [markdown]
# Analisa:

# %% [markdown]
# ---
#
# Berdasarkan catplot, terlihat bahwa panjang paruh/ bill length dari penguin jenis kelamin jantan cenderung lebih panjang dari betina.
#
# ---
#
# Berdasarkan scatter plot, terlihat bahwa hubungan antara bodymass dengan flipper length cenderung linear. Namun, untuk hubungan antara bodymass dan bill length cenderung tidak memiliki hubungan karena tidak terdapat perubahan warna titik pada grafik yang berpola dan cenderung acak.
#
# ---

# %% [markdown]
# # Soal 5. Multivariate Analisis
#
# *   Dengan menggunakan seaborn, buatlah sebuah pairplot keseluruhan data feature pada dataset (df) dengan argumen kind='bar', seperti expected di bawah:
# *   Jelaskan hasil analisa dari multivariate yang dihasilkan

# %%
print("Pair plot")
sns.pairplot(df)
plt.show()
# Out:
# Pair plot

# %% [markdown]
# Expected output:
#
# Pair plot
#
# ![](https://drive.google.com/uc?id=1td8WAZLJEW5BPTq-wEJyZ4soRNNLXfqX)

# %% [markdown]
# Analisa:

# %% [markdown]
# Hubungan diagonal pada grafik di atas menunjukan persebaran frekuensi data untuk tiap variabel.
#
# ---
# Untuk hubungan bodymass sebagai variabel terikat dan 3 variabel sisanya sebagai variabel bebas, dapat terlihat hubungan antara bodymass dengan flipperlength dan bill length cenderung memiliki hubungan yang linear, yang mana hubungannya dengan flipper length memiliki nilai korelasi lebih besar karena saat dengan bill lenth terlihat bahwa ada data yang cenderung lebih tersebar dan tidak berpola mendekati garis linear regresi. Untuk hubungan antara bill depth vs bodymass terlihat ada kecendrungan klusterisasi suatu nilai.
#
#
# ---
# Untuk hubungan flipper length sebagai variabel terikat dan 3 variabel sisanya sebagai variabel bebas, dapat terlihat hubungan antara flipperlength dengan dengan bill length cenderung memiliki hubungan yang linear. Untuk hubungan antara flipper length vs bill depth terlihat ada kecendrungan pola klusterisasi untuk pasangan suatu nilai yang mendeskripsika karakteristik tertentu. Untuk analisis flipper length vs body mass sama seperti analisis sebelumnya.
#
#
#
# ---
# Untuk hubungan bill depth sebagai variabel terikat dan 3 variabel sisanya sebagai variabel bebas, dapat terlihat hubungan antara bill depth vs bill length tidak memiliki hubungan karena cenderung tersebar acak. Sedangkan hubungan dengan variabel lainnya sama seperti analisis sebelumnya pada analisis flipper length dan bodymass.
